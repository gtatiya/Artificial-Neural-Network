# %% [markdown]
# # HAR CNN + LSTM training
# https://github.com/bhimmetoglu/time-series-medicine/blob/master/HAR/HAR-CNN_LSTM.ipynb

# %%
# Imports
import numpy as np
import os, shutil
from utils.utilities import *
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Data Set Information:
# https://archive.ics.uci.edu/ml/datasets/human+activity+recognition+using+smartphones
#
# The experiments have been carried out with a group of 30 volunteers within an age bracket of 19-48 years.
# Each person performed six activities (WALKING, WALKING_UPSTAIRS, WALKING_DOWNSTAIRS, SITTING, STANDING, LAYING) wearing a smartphone (Samsung Galaxy S II) on the waist.
# Using its embedded accelerometer and gyroscope, we captured 3-axial linear acceleration and 3-axial angular velocity at a constant rate of 50Hz.
# The experiments have been video-recorded to label the data manually.
# The obtained dataset has been randomly partitioned into two sets, where 70% of the volunteers was selected for generating the training data and 30% the test data.
#
# The sensor signals (accelerometer and gyroscope) were pre-processed by applying noise filters and then sampled in fixed-width sliding windows of 2.56 sec and 50% overlap (128 readings/window).
# The sensor acceleration signal, which has gravitational and body motion components, was separated using a Butterworth low-pass filter into body acceleration and gravity.
# The gravitational force is assumed to have only low frequency components, therefore a filter with 0.3 Hz cutoff frequency was used.
# From each window, a vector of features was obtained by calculating variables from the time and frequency domain.

# %% [markdown]
# ## Prepare data

# %%
X_train, labels_train, list_ch_train = read_data(data_path="../../../Datasets/UCI HAR Dataset/", split="train") # train

X_test, labels_test, list_ch_test = read_data(data_path="../../../Datasets/UCI HAR Dataset/", split="test") # test

assert list_ch_train == list_ch_test, "Mistmatch in channels!"

# %%
# How data is represented?
# 7352+2947=10299

print("Train")
print(type(X_train))
print(X_train.shape)
#print(X_train)
print(labels_train.shape)
print(labels_train)
print("MAX: ", max(labels_train)) # There are 6 labels (WALKING, WALKING_UPSTAIRS, WALKING_DOWNSTAIRS, SITTING, STANDING, LAYING)
print("MIN: ", min(labels_train))
print(list_ch_train)

print("\nTest")
print(type(X_test))
print(X_test.shape)
#print(X_test)
print(labels_test.shape)
print(labels_test)
print(list_ch_test)
# Out:
# Train
# <class 'numpy.ndarray'>
# (7352, 128, 9)
# (7352,)
# [5 5 5 ... 2 2 2]
# MAX:  6
# MIN:  1
# ['body_acc_x', 'body_acc_y', 'body_acc_z', 'body_gyro_x', 'body_gyro_y', 'body_gyro_z', 'total_acc_x', 'total_acc_y', 'total_acc_z']
#
# Test
# <class 'numpy.ndarray'>
# (2947, 128, 9)
# (2947,)
# [5 5 5 ... 2 2 2]
# ['body_acc_x', 'body_acc_y', 'body_acc_z', 'body_gyro_x', 'body_gyro_y', 'body_gyro_z', 'total_acc_x', 'total_acc_y', 'total_acc_z']

# %% [raw]
# print(X_train)

# %%
# Standardize
X_train, X_test = standardize(X_train, X_test)

# %% [raw]
# print(X_train)

# %% [markdown]
# Train/Validation Split

# %%
X_tr, X_vld, lab_tr, lab_vld = train_test_split(X_train, labels_train, stratify = labels_train, random_state = 123)

# %%
print("Validation")
print(type(X_tr))
print(X_tr.shape)
print(lab_tr.shape)
print(X_vld.shape)
print(lab_vld.shape)
# 5514+1838=7352
# Out:
# Validation
# <class 'numpy.ndarray'>
# (5514, 128, 9)
# (5514,)
# (1838, 128, 9)
# (1838,)

# %% [markdown]
# One-hot encoding:

# %%
y_tr = one_hot(lab_tr)
y_vld = one_hot(lab_vld)
y_test = one_hot(labels_test)

# %% [raw]
# print(y_tr.shape)
# print(y_tr)
# print(y_vld.shape)
# print(y_vld)
# print(y_test.shape)
# print(y_test)

# %%
# Imports
import tensorflow as tf

# %% [markdown]
# ### Hyperparameters

# %%
lstm_size = 27         # 3 times the amount of channels (3*9)
lstm_layers = 2        # Number of layers
batch_size = 600       # Batch size
seq_len = 128          # Number of steps
learning_rate = 0.0001  # Learning rate (default is 0.001)
epochs = 1000

# Fixed
n_classes = 6
n_channels = 9

# %% [markdown]
# ### Construct the graph
# Placeholders

# %%
graph = tf.Graph()

# Construct placeholders
with graph.as_default():
    inputs_ = tf.placeholder(tf.float32, [None, seq_len, n_channels], name = 'inputs')
    labels_ = tf.placeholder(tf.float32, [None, n_classes], name = 'labels')
    keep_prob_ = tf.placeholder(tf.float32, name = 'keep')
    learning_rate_ = tf.placeholder(tf.float32, name = 'learning_rate')

# %%
print(inputs_)
print(labels_)
print(keep_prob_)
print(learning_rate_)
# Out:
# Tensor("inputs:0", shape=(?, 128, 9), dtype=float32)
# Tensor("labels:0", shape=(?, 6), dtype=float32)
# Tensor("keep:0", dtype=float32)
# Tensor("learning_rate:0", dtype=float32)

# %% [markdown]
# Build Convolutional Layer(s)
#
# Questions:
# * Should we use a different activation? Like tf.nn.tanh?
# * Should we use pooling? average or max?

# %%
# Convolutional layers
with graph.as_default():
    with tf.name_scope('Model'):
        # (batch, 128, 9) --> (batch, 128, 18)
        conv1 = tf.layers.conv1d(inputs=inputs_, filters=18, kernel_size=2, strides=1, padding='same', activation = tf.nn.relu)
        n_ch = n_channels *2

# %% [markdown]
# Now, pass to LSTM cells

# %%
with graph.as_default():
    with tf.name_scope('Model'):
        # Construct the LSTM inputs and LSTM cells
        lstm_in = tf.transpose(conv1, [1,0,2]) # reshape into (seq_len, batch, channels)
        lstm_in = tf.reshape(lstm_in, [-1, n_ch]) # Now (seq_len*N, n_channels)

        # To cells
        lstm_in = tf.layers.dense(lstm_in, lstm_size, activation=None) # or tf.nn.relu, tf.nn.sigmoid, tf.nn.tanh?

        # Open up the tensor into a list of seq_len pieces
        lstm_in = tf.split(lstm_in, seq_len, 0) # 128 tensors of [batch, 27]

        # Add LSTM layers
        lstm = tf.contrib.rnn.BasicLSTMCell(lstm_size)
        drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob_) #Operator adding dropout to inputs and outputs of the given cell
        cell = tf.contrib.rnn.MultiRNNCell([drop] * lstm_layers) #RNN cell composed sequentially of multiple simple cells
        initial_state = cell.zero_state(batch_size, tf.float32) # ???

# %%
sess = tf.Session()
batch_temp = 10
seq_len_temp = 128
lstm_size_temp = 27
keep_prob_temp = 0.5
lstm_layers_temp = 2

input_temp = tf.random_normal([batch_temp, 128, 9])
print(input_temp)
conv1_temp = tf.layers.conv1d(inputs=input_temp, filters=18, kernel_size=2, strides=1, padding='same', activation = tf.nn.relu)
print(conv1_temp)
lstm_in_temp = tf.transpose(conv1_temp, [1, 0, 2]) # reshape into (seq_len, batch, channels)
print(lstm_in_temp)
lstm_in_temp = tf.reshape(lstm_in_temp, [-1, 18]) # Now (seq_len*N, n_channels)
print(lstm_in_temp)
lstm_in_temp = tf.layers.dense(lstm_in_temp, lstm_size_temp, activation=None) # or tf.nn.relu, tf.nn.sigmoid, tf.nn.tanh?
print(lstm_in_temp)
lstm_in_temp = tf.split(lstm_in_temp, seq_len_temp, 0)
# print(lstm_in_temp) # 128 tensors of [batch, 27]

lstm_temp = tf.contrib.rnn.BasicLSTMCell(lstm_size_temp)
print(lstm_temp)
drop_temp = tf.contrib.rnn.DropoutWrapper(lstm_temp, output_keep_prob=keep_prob_temp) #Operator adding dropout to inputs and outputs of the given cell
print(drop_temp)
cell_temp = tf.contrib.rnn.MultiRNNCell([drop_temp] * lstm_layers_temp) #RNN cell composed sequentially of multiple simple cells
print(cell_temp)
initial_state_temp = cell_temp.zero_state(batch_temp, tf.float32)
print(initial_state_temp)
# Out:
# Tensor("random_normal:0", shape=(10, 128, 9), dtype=float32)
# Tensor("conv1d/Relu:0", shape=(10, 128, 18), dtype=float32)
# Tensor("transpose:0", shape=(128, 10, 18), dtype=float32)
# Tensor("Reshape:0", shape=(1280, 18), dtype=float32)
# Tensor("dense/BiasAdd:0", shape=(1280, 27), dtype=float32)
# ...
# (LSTMStateTuple(c=<tf.Tensor 'MultiRNNCellZeroState/DropoutWrapperZeroState/BasicLSTMCellZeroState/zeros:0' shape=(10, 27) dtype=float32>, h=<tf.Tensor 'MultiRNNCellZeroState/DropoutWrapperZeroState/BasicLSTMCellZeroState/zeros_1:0' shape=(10, 27) dtype=float32>), LSTMStateTuple(c=<tf.Tensor 'MultiRNNCellZeroState/DropoutWrapperZeroState_1/BasicLSTMCellZeroState/zeros:0' shape=(10, 27) dtype=float32>, h=<tf.Tensor 'MultiRNNCellZeroState/DropoutWrapperZeroState_1/BasicLSTMCellZeroState/zeros_1:0' shape=(10, 27) dtype=float32>))

# %% [markdown]
# Define forward pass and cost function:

# %%
with graph.as_default():
    with tf.name_scope('Model'):
        outputs, final_state = tf.contrib.rnn.static_rnn(cell, lstm_in, dtype=tf.float32, initial_state = initial_state)

        # We only need the last output tensor to pass into a classifier
        logits = tf.layers.dense(outputs[-1], n_classes, name='logits')

        # Cost function and optimizer
        with tf.name_scope('Loss'):
            cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=labels_))
            #optimizer = tf.train.AdamOptimizer(learning_rate_).minimize(cost) # No grad clipping
        tf.summary.scalar("loss", cost) # Create a summary to monitor loss_op tensor

        # Grad clipping
        train_op = tf.train.AdamOptimizer(learning_rate_)

        gradients = train_op.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients]
        optimizer = train_op.apply_gradients(capped_gradients)

        # Accuracy
        correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(labels_, 1))
        with tf.name_scope('Accuracy'):
            accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')
        tf.summary.scalar("accuracy", accuracy) # Create a summary to monitor accuracy tensor

# %%
n_classes_temp = 6
outputs_temp, _ = tf.contrib.rnn.static_rnn(cell_temp, lstm_in_temp, dtype=tf.float32, initial_state = initial_state_temp)
# print(outputs_temp) # 128 tensors of [batch, 27]
logits_temp = tf.layers.dense(outputs_temp[-1], n_classes_temp, name='logits_temp')
print(logits_temp)
# Out:
# Tensor("logits_temp/BiasAdd:0", shape=(10, 6), dtype=float32)

# %% [markdown]
# ### Train the network

# %%
if os.path.exists("cnn_lstm_har_logs/"):
    shutil.rmtree("cnn_lstm_har_logs/")

# %%
validation_acc = []
validation_loss = []

train_acc = []
train_loss = []

with graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=graph) as sess:
    sess.run(tf.global_variables_initializer())
    iteration = 1
    
    summary_op = tf.summary.merge_all() # Merge all summaries into a single op
    summary_writer = tf.summary.FileWriter("cnn_lstm_har_logs/", graph=tf.get_default_graph())
    
    for e in range(epochs):
        # Initialize 
        state = sess.run(initial_state)
        
        # Loop over batches
        for x,y in get_batches(X_tr, y_tr, batch_size):
            
            # Feed dictionary
            feed = {inputs_ : x, labels_ : y, keep_prob_ : 0.5, initial_state : state, learning_rate_ : learning_rate}
            
            loss, _ , state, acc = sess.run([cost, optimizer, final_state, accuracy], feed_dict = feed)
            train_acc.append(acc)
            train_loss.append(loss)
            
            # Write logs at every iteration
            summary_str = sess.run(summary_op, feed_dict=feed)
            summary_writer.add_summary(summary_str, e)
            
            # Save checkpoint
            #saver.save(sess, "cnn_lstm_har_logs/model-checkpoint", e) # Is slows down a lot
            
            # Print at each 5 iters
            if (iteration % 5 == 0):
                print("Epoch: {}/{}".format(e, epochs),
                      "Iteration: {:d}".format(iteration),
                      "Train loss: {:6f}".format(loss),
                      "Train acc: {:.6f}".format(acc))
            
            # Compute validation loss at every 25 iterations
            if (iteration%25 == 0):
                
                # Initiate for validation set
                val_state = sess.run(cell.zero_state(batch_size, tf.float32))
                
                val_acc_ = []
                val_loss_ = []
                for x_v, y_v in get_batches(X_vld, y_vld, batch_size):
                    # Feed
                    feed = {inputs_ : x_v, labels_ : y_v, keep_prob_ : 1.0, initial_state : val_state}
                    
                    # Loss
                    loss_v, state_v, acc_v = sess.run([cost, final_state, accuracy], feed_dict = feed)
                    
                    val_acc_.append(acc_v)
                    val_loss_.append(loss_v)
                
                # Print info
                print("Epoch: {}/{}".format(e, epochs),
                      "Iteration: {:d}".format(iteration),
                      "Validation loss: {:6f}".format(np.mean(val_loss_)),
                      "Validation acc: {:.6f}".format(np.mean(val_acc_)))
                
                # Store
                validation_acc.append(np.mean(val_acc_))
                validation_loss.append(np.mean(val_loss_))
            
            # Iterate 
            iteration += 1
    
    saver.save(sess,"cnn_lstm_har_logs/har.ckpt")
# Out:
# Epoch: 0/1000 Iteration: 5 Train loss: 1.804776 Train acc: 0.148333
# Epoch: 1/1000 Iteration: 10 Train loss: 1.796255 Train acc: 0.176667
# Epoch: 1/1000 Iteration: 15 Train loss: 1.793649 Train acc: 0.180000
# Epoch: 2/1000 Iteration: 20 Train loss: 1.773129 Train acc: 0.233333
# Epoch: 2/1000 Iteration: 25 Train loss: 1.763047 Train acc: 0.233333
# Epoch: 2/1000 Iteration: 25 Validation loss: 1.754864 Validation acc: 0.307778
# Epoch: 3/1000 Iteration: 30 Train loss: 1.762858 Train acc: 0.260000
# Epoch: 3/1000 Iteration: 35 Train loss: 1.748123 Train acc: 0.271667
# Epoch: 4/1000 Iteration: 40 Train loss: 1.741099 Train acc: 0.308333
# Epoch: 4/1000 Iteration: 45 Train loss: 1.728210 Train acc: 0.318333
# Epoch: 5/1000 Iteration: 50 Train loss: 1.708678 Train acc: 0.355000
# Epoch: 5/1000 Iteration: 50 Validation loss: 1.699279 Validation acc: 0.432222
# Epoch: 6/1000 Iteration: 55 Train loss: 1.702999 Train acc: 0.343333
# ...

# %%
# Plot training and test loss
t = np.arange(iteration-1)

plt.figure(figsize = (6,6))
plt.plot(t, np.array(train_loss), 'r-', t[t % 25 == 0], np.array(validation_loss), 'b*')
plt.xlabel("iteration")
plt.ylabel("Loss")
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
# Plot Accuracies
plt.figure(figsize = (6,6))

plt.plot(t, np.array(train_acc), 'r-', t[t % 25 == 0], validation_acc, 'b*')
plt.xlabel("iteration")
plt.ylabel("Accuray")
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %% [markdown]
# ## Evaluate on test set

# %%
test_acc = []

with tf.Session(graph=graph) as sess:
    # Restore
    saver.restore(sess, tf.train.latest_checkpoint('cnn_lstm_har_logs'))
    
    for x_t, y_t in get_batches(X_test, y_test, batch_size):
        feed = {inputs_: x_t,
                labels_: y_t,
                keep_prob_: 1}
        
        batch_acc = sess.run(accuracy, feed_dict=feed)
        test_acc.append(batch_acc)
    print("Test accuracy: {:.6f}".format(np.mean(test_acc)))
# Out:
# INFO:tensorflow:Restoring parameters from cnn_lstm_har_logs\har.ckpt
# Test accuracy: 0.871667
